# %% [markdown]
# ## Import

# %%
import warnings
from notebook_utils import reload_classes, reload_data_classes, reload_lagacy

warnings.filterwarnings("ignore", message=".*boundary.*data discontinuities.*")
warnings.filterwarnings("ignore", message="FigureCanvasAgg is non-interactive, and thus cannot be shown")

# %% [markdown]
# # Main

# %% [markdown]
# ### Load

# %%
EEGSubjectData = reload_data_classes()
release = 1
data_dir = f'/mount/NAS-public-dataset/HBN-EEG'
subject_data = EEGSubjectData(data_dir)

# %%
EEGController, EEGUI = reload_classes()
controller = EEGController(subject_data)

# %% [markdown]
# ### UI

# %% [markdown]
# 81.9444
#
# 1.6324
#
# 69-76,81-83,88,89

# %%
# %matplotlib inline
ui = EEGUI(controller)
ui.show()
# Out:
# VBox(children=(ToggleButtons(description='Input Type:', layout=Layout(width='auto'), options=(('Single subject…

# %%
Legacy_EEGUI = reload_lagacy()
legacy_ui = Legacy_EEGUI(controller)
legacy_ui.show()
# Out:
# VBox(children=(Dropdown(description='Subject:', options=('sub-NDARAA306NT2', 'sub-NDARAA504CRN', 'sub-NDARAA94…
