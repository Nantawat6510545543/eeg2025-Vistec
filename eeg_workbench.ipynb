# %% [markdown]
# ## Import

# %%
import warnings
import os
from dotenv import load_dotenv
load_dotenv()
from notebook_utils import reload_classes, reload_data_classes

warnings.filterwarnings("ignore", message=".*boundary.*data discontinuities.*")
warnings.filterwarnings("ignore", message="FigureCanvasAgg is non-interactive, and thus cannot be shown")

# %% [markdown]
# # Main

# %% [markdown]
# ### Load

# %%
DATA_DIR = os.getenv("DATA_DIR") or os.getenv("EEG_DATA_DIR")
DATA_DIR
# Out:
# '/home/interface/Documents/mount/NAS-public-dataset/HBN-EEG'

# %%
EEGSubjectData = reload_data_classes()
subject_data = EEGSubjectData(DATA_DIR)
# Out:
# 14:46:56 INFO [eegkit.models.subject_model] EEGSubjectModel initialized (ParticipantManager: 0.00s)

# %%
EEGController, EEGUI = reload_classes()
controller = EEGController(subject_data)

# %% [markdown]
# ### UI

# %% [markdown]
# 81.9444
#
# 1.6324
#
# 69-76,81-83,88,89

# %%
# %matplotlib inline
ui = EEGUI(controller)
# Out:
# 14:46:56 INFO [eegkit.models.participant_manager] Finding participants_combine.tsv on /home/interface/Documents/mount/NAS-public-dataset/HBN-EEG/participants_combine.tsv
# 14:46:56 INFO [eegkit.models.participant_manager] Found participants_combine.tsv
# 14:46:56 INFO [eegkit.models.participant_manager] Loaded participants_combine.tsv in 0.07s (rows=2825, cols=34)
# 14:46:56 INFO [eegkit.models.participant_manager] Discovered 10 release dirs in 0.00s
# Discover tasks: subjects:   0%|          | 0/2825 [00:00<?, ?it/s]
# 14:47:22 INFO [eegkit.models.participant_manager] Discovered tasks for 2825 subjects; scanned 23346 files in 25.75s

# %%
ui.show()
# Out:
# VBox(children=(ToggleButtons(description='Input Type:', layout=Layout(width='auto'), options=(('Single subject…
